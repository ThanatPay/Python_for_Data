# %% [markdown]
# ## Matplotlib: Visualization with Python
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats.
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.
#
# ### Plot Types
# • https://matplotlib.org/stable/plot_types/index.html

# %% [markdown]
# ![Screenshot%202566-06-11%20at%2016.59.31.png](attachment:Screenshot%202566-06-11%20at%2016.59.31.png)

# %% [markdown]
# ### Matplotlib components
#  - Figure : overall space that contain one or more plots
#  - Axes : individual plot in Figure

# %% [markdown]
# ![Screenshot%202566-06-11%20at%2017.50.19.png](attachment:Screenshot%202566-06-11%20at%2017.50.19.png)

# %%
# import library matplotlib
import matplotlib.pyplot as plt

# %%
# create a figure containing a single plot (axis)
fig, ax = plt.subplots()

# %%
# figure with 2 plots in rows
fig, ax = plt.subplots(1,2, figsize=(12,6))

# %%
# figure with 2 plots in columns
fig, ax = plt.subplots(2,1, figsize=(12,6))

# %% [markdown]
# ## Simple Plot

# %%
import numpy as np

# %% [markdown]
# ### Simple plot using pyplot

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)

fig, ax = plt.subplots()
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('About as simple as it gets')

# save figure
fig.savefig('test2.png')

# visualize plot
plt.show()

# %% [markdown]
# ### Simple plot using axes

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets')
ax.grid()

# save figure
fig.savefig('test1.png')

# visualize plot
plt.show()
